# %% [markdown]
# <a href="https://colab.research.google.com/github/jms9896/2022-1_HW/blob/main/ImageProcessing/ImageProcessing_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-21281453-74dd-4011-bf37-4cbf4e1fc6bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21281453-74dd-4011-bf37-4cbf4e1fc6bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BOAT512.raw.raw to BOAT512.raw.raw
# Saving lena_bmp_512x512_new.bmp to lena_bmp_512x512_new.bmp
# Saving lena_raw_512x512.raw to lena_raw_512x512.raw

# %%
import matplotlib.pyplot as plt
# 이미지 불러오기

#lena_raw = plt.imread('/content/lena_raw_512x512.raw')
lena_bmp = plt.imread('/content/lena_bmp_512x512_new.bmp')
#plt.imshow(lena_bmp, cmap = 'gray')
#plt.show()

# %% [markdown]
# 1.
# P_e=n_1/n_0 공식을 이용
# Roberts
# Sobel
# Prewitt
# 5*5 stochastic gradient
# SNR = 8dB
# 픽셀의 위치인 location(m,n)은
# g(m,n) = sqrt( g_x(m,n) ^2 + g_y(m,n) ^2 )
# THRESH값이 150 초과여야한다.
# 512*512 BMP 또는 RAW Lena 이용해야한다.

# %% [markdown]
# 2.
# 3*3 Low-pass와 median filters를 비교.
# SNR = 9dB
# 오브젝트 비교를 위해서 MSE(Mean Square Error)값을 각 결과마다 얻어라.
# 512*512 BOAT.raw 이용하셈

# %%
# Out:
# '\n2.\n3*3 Low-pass와 median filters를 비교.\n'
